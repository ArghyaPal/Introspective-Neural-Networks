# %%
import torch
from sampling import Synthesis

# %%
class toy_example(torch.nn.Module):
    def __init__(self, size=(10, 1, 5, 5), std=0.3):
        super(toy_example, self).__init__()
        self.X = torch.nn.Parameter(torch.empty(size).normal_(mean=0, std=std));
        self.Y = torch.nn.Parameter(torch.empty(size).normal_(mean=0, std=std));
    
    def forward(self):
        return 0;
    
    def to_synth(self):
        '''
        Multi-dimensional parabola function with leaves going down. 
        During maximization should converge to zero
        '''
        return -((self.X*self.Y)**2).sum(dim=(-1, -2));

# %%
m = toy_example();
s = Synthesis(init_std=0.3);
s.sample(m, num_iter=1000, learning_rate=1e-1)
# Out:
# tensor([[[[ 3.0569e-01,  4.5096e-01,  3.9090e-02, -6.2224e-08,  1.4076e-01],
#           [-2.8337e-01, -2.0427e-02, -2.3355e-01,  9.3388e-12, -3.6778e-07],
#           [ 7.5060e-08, -2.1621e-13, -7.5897e-02, -6.6293e-22, -6.9841e-09],
#           [-1.4759e-01,  3.7222e-04,  2.2023e-01,  2.1473e-05,  9.0854e-15],
#           [-6.8483e-04, -1.2548e-22, -1.7679e-01, -7.3475e-04,  1.0507e-19]]],
#
#
#         [[[-3.0508e-05,  1.6736e-04, -2.3226e-10, -6.1492e-02,  2.6367e-04],
#           [-5.1874e-28, -6.0672e-16,  1.9122e-07, -9.5001e-02, -1.4874e-08],
#           [-2.9363e-02,  1.2025e-01,  2.3022e-06, -7.6356e-04, -5.0519e-04],
#           [ 8.9397e-04,  1.6485e-03, -5.4168e-17,  1.1282e-01,  4.9460e-01],
#           [ 8.1008e-04,  1.1128e-02, -6.4404e-09, -1.0225e-06, -1.3562e-02]]],
#
#
#         [[[ 2.8043e-01,  1.9801e-02,  4.6284e-02, -2.8001e-04, -2.4587e-02],
#           [ 4.4647e-10, -7.8934e-07,  1.3812e-03, -1.6846e-22,  1.6313e-02],
#           [-6.3518e-09,  3.3499e-06, -1.2970e-05,  6.8134e-13,  8.7544e-03],
#           [ 5.9897e-09, -1.5897e-10, -4.2039e-45,  3.2797e-17, -7.3393e-04],
#           [-1.1141e-09, -8.0711e-22,  3.2781e-20, -5.8433e-15,  7.1297e-04]]],
#
#
#         [[[ 4.7307e-03, -1.2440e-05, -1.1932e-14, -1.3125e-01, -4.7701e-19],
#           [ 1.3098e-06, -6.3211e-02, -1.8250e-03, -1.2541e-02, -2.6876e-06],
#           [ 4.8936e-16, -5.1401e-05,  6.8293e-04,  1.0000e-01, -2.1318e-01],
#           [ 1.4910e-01,  4.0777e-05, -7.3397e-05,  3.9401e-01, -3.5503e-15],
#           [-3.0162e-06,  2.6967e-11, -1.2510e-01, -9.6464e-02, -1.2162e-09]]],
#
#
#         [[[-1.2499e-03, -9.6172e-22,  6.7492e-25, -7.7940e-03,  1.1580e-04],
#           [ 1.0648e-03, -2.0387e-02, -5.1053e-04,  7.6214e-10, -3.6461e-06],
#           [ 6.1421e-28,  4.3155e-07, -5.6052e-45,  5.2327e-01,  1.2414e-03],
#           [ 1.3961e-02, -3.8215e-33, -1.9275e-25, -7.7257e-02,  1.6638e-02],
#           [-8.2537e-03,  1.3604e-01, -1.6544e-06,  1.1921e-12, -2.5573e-02]]],
#
#
#         [[[ 4.3456e-20, -2.1476e-01,  9.0332e-02, -4.0113e-03,  3.6113e-01],
#           [ 6.1803e-09, -7.5783e-03,  3.3574e-01,  2.2414e-02,  7.2494e-04],
#           [ 3.7438e-29,  5.4250e-05, -1.9833e-15, -7.8468e-07,  2.8574e-18],
#           [ 1.3052e-01,  1.8260e-08,  2.9263e-02,  2.8968e-01,  1.0882e-10],
#           [-1.0595e-07, -3.4707e-17,  8.8902e-02, -9.9174e-03,  4.2039e-45]]],
#
#
#         [[[-3.1758e-02, -3.5084e-04, -4.3149e-10, -1.6226e-01, -1.0604e-04],
#           [ 8.8453e-02, -5.6321e-12,  7.0291e-07, -1.2773e-01, -1.3985e-04],
#           [ 1.6842e-09, -1.1076e-19,  9.3492e-13,  1.4031e-11,  4.1306e-05],
#           [-2.1503e-02, -1.5108e-08,  4.2039e-45, -5.6052e-45, -2.2438e-03],
#           [ 1.5983e-03, -2.8836e-01, -9.3825e-02,  8.4689e-03,  4.3420e-02]]],
#
#
#         [[[-1.2824e-04,  1.7459e-27, -2.8343e-09,  2.4360e-09,  5.9409e-03],
#           [-1.4129e-21,  8.4710e-02,  1.8600e-04, -1.8351e-03,  4.2512e-02],
#           [ 8.9568e-02,  4.6270e-02, -9.2380e-03,  9.0638e-12, -2.6969e-08],
#           [-8.9118e-17,  9.9019e-12,  1.2171e-01,  1.1369e-02,  1.3750e-07],
#           [ 1.6992e-10, -1.6848e-05,  2.9940e-08,  3.2620e-03,  1.7222e-01]]],
#
#
#         [[[-2.0879e-02,  1.7616e-09, -2.7997e-17, -4.5026e-05, -2.1019e-44],
#           [-4.0480e-03,  1.6271e-02,  9.5388e-04, -1.8547e-01,  1.5768e-01],
#           [-4.3358e-03, -2.0713e-11,  9.6400e-05, -6.1897e-03, -4.4116e-04],
#           [-1.0826e-13, -1.5934e-02, -3.2174e-06, -8.3457e-06,  3.6411e-20],
#           [-1.8619e-21,  2.0991e-20,  1.7529e-03,  5.9405e-03, -8.4072e-03]]],
#
#
#         [[[ 1.9498e-01, -1.7188e-08, -9.0647e-10, -3.7622e-12,  4.2039e-45],
#           [ 3.5970e-02,  2.1751e-01,  1.8263e-24,  9.4709e-03, -1.9194e-05],
#           [-1.3034e-15,  1.7166e-10, -4.4072e-01, -2.3704e-07,  5.2968e-05],
#           [-1.4400e-02,  3.5082e-09, -8.5575e-13, -2.1871e-02,  1.5023e-01],
#           [ 4.2039e-45, -4.9848e-21,  5.8366e-04, -1.7525e-01, -9.5674e-02]]]])
