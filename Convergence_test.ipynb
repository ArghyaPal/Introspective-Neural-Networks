# %%
import torch
from sampling import Synthesis

# %%
class toy_example(torch.nn.Module):
    def __init__(self, size=(10, 1, 5, 5), std=0.3):
        super(toy_example, self).__init__()
        self.X = torch.nn.Parameter(torch.empty(size).normal_(mean=0, std=std));
    
    def forward(self):
        return 0;
    
    def to_synth(self):
        '''
        Multi-dimensional parabola function with leaves going down. 
        During maximization should converge to zero
        '''
        return -((self.X)**2).sum(dim=(-1, -2));

# %%
m = toy_example();
s = Synthesis(init_std=0.3);
s.sample(m, num_iter=100, learning_rate=1e-1)
# Out:
# tensor([[[[-1.7418e-10, -9.3712e-11,  4.7909e-11, -3.6606e-11, -6.5050e-11],
#           [ 2.1626e-11,  5.1553e-11, -1.1356e-10, -5.0238e-11,  1.0069e-10],
#           [-8.7790e-11, -8.8845e-11,  3.8279e-11,  1.0936e-10,  1.2902e-11],
#           [ 5.0721e-11,  3.8221e-11,  5.0534e-11,  3.6133e-11,  1.3481e-11],
#           [ 4.6162e-12, -5.4307e-11, -8.8679e-11,  2.3554e-11, -1.2218e-10]]],
#
#
#         [[[-9.3580e-11,  4.3222e-11,  1.2314e-10, -1.2064e-11, -8.2113e-11],
#           [ 1.9900e-12, -1.6555e-11, -8.1623e-11,  1.3278e-11, -1.1579e-11],
#           [-4.2159e-11,  5.0850e-11, -1.0002e-11,  1.6293e-11, -2.5857e-11],
#           [-7.8154e-11, -8.8986e-11,  1.6849e-11, -3.9066e-11, -2.9423e-12],
#           [-9.6030e-12,  2.5667e-11, -1.2856e-13, -3.9354e-11, -3.7305e-11]]],
#
#
#         [[[ 3.8389e-11,  3.1629e-11,  9.9757e-12, -1.0181e-11, -1.0597e-10],
#           [-9.3443e-12, -6.1826e-11, -4.4332e-11, -4.2556e-11, -3.0776e-11],
#           [-9.3562e-11, -1.6948e-11,  4.2818e-11,  5.9997e-11,  5.6238e-11],
#           [ 7.1421e-11,  2.4619e-11,  2.5381e-11,  1.7260e-11,  4.4664e-11],
#           [-1.3728e-10, -7.3338e-11,  3.8302e-11, -4.3146e-12,  8.5467e-11]]],
#
#
#         [[[-1.9465e-11,  2.9601e-11, -3.8441e-11,  5.9493e-11,  9.2340e-11],
#           [ 4.2159e-11, -2.7856e-12,  7.1067e-11, -5.7932e-12, -1.8907e-10],
#           [-5.5577e-11,  1.2173e-10, -6.2119e-11,  4.8309e-11, -2.3848e-11],
#           [ 2.3136e-11, -1.5641e-11,  6.4196e-12,  5.5708e-11,  4.4045e-11],
#           [-8.1126e-11,  9.6939e-11, -3.4857e-11,  2.6437e-11, -1.1686e-11]]],
#
#
#         [[[ 6.4266e-11, -6.5885e-11, -8.5383e-11,  2.8099e-11, -3.7062e-11],
#           [ 2.3328e-11,  3.9746e-11, -1.1881e-11,  2.6284e-11,  1.1929e-11],
#           [ 2.0786e-11, -1.1344e-11,  8.3079e-11, -4.7913e-11,  1.1443e-10],
#           [-4.6225e-11, -4.2250e-11,  9.5028e-11,  1.2756e-10,  2.7158e-11],
#           [-7.5187e-11,  8.6465e-11, -1.5611e-11,  8.4271e-13,  6.6723e-11]]],
#
#
#         [[[-1.0089e-10, -1.3730e-10, -4.4015e-11, -5.3689e-11,  5.8493e-12],
#           [-1.9091e-12,  7.7615e-11,  2.5231e-11,  5.6909e-11, -1.1379e-10],
#           [ 7.4150e-12, -8.7148e-11,  1.4656e-11,  6.8841e-11,  5.2100e-12],
#           [ 2.4108e-11,  4.2665e-11,  7.1074e-11, -3.0943e-11, -6.2094e-11],
#           [-2.9299e-11,  5.4403e-11,  6.1487e-11,  8.0889e-11,  1.4474e-10]]],
#
#
#         [[[-4.9444e-11,  8.2466e-11,  3.3535e-11, -2.2322e-11,  1.3449e-10],
#           [-7.3395e-11, -6.2162e-11, -4.3291e-11,  9.6784e-11,  1.0559e-10],
#           [ 3.2715e-11, -5.3728e-11, -1.5511e-11, -7.8999e-11,  3.0314e-11],
#           [ 3.3003e-11,  4.6141e-11,  1.7885e-11, -2.7697e-11,  1.0622e-10],
#           [ 1.9176e-11,  4.3563e-11, -7.4757e-11, -2.5210e-11,  5.4251e-11]]],
#
#
#         [[[-6.2998e-12,  5.0996e-11,  5.6427e-11,  6.3486e-11,  4.3495e-11],
#           [ 6.8473e-11,  1.2125e-10, -3.8824e-11, -9.2630e-11, -8.0228e-11],
#           [-1.1806e-11, -3.8861e-11,  2.3085e-12, -6.5154e-11, -9.9771e-11],
#           [ 3.1386e-11,  1.1833e-11, -7.4083e-11, -2.2869e-12,  1.1517e-11],
#           [ 1.8264e-11, -7.4690e-11,  4.5478e-11,  4.0204e-11,  4.6908e-11]]],
#
#
#         [[[-3.0610e-11, -4.3688e-11,  1.4751e-11, -4.7331e-12,  8.5244e-11],
#           [ 2.1304e-11,  7.1635e-11,  4.8987e-11, -5.7199e-11, -9.9945e-12],
#           [-9.2114e-11, -6.0613e-11, -5.6606e-11,  1.2392e-10, -7.3796e-12],
#           [-8.8693e-12, -1.1727e-10, -2.6251e-11,  8.1404e-11, -6.9081e-11],
#           [ 2.5814e-11,  2.0722e-11,  6.2948e-11, -9.1867e-11,  1.7291e-11]]],
#
#
#         [[[-7.0954e-11, -2.1759e-11,  3.7285e-12,  4.7935e-11, -6.2268e-12],
#           [-7.6596e-11,  8.0921e-11,  7.1873e-11,  1.0635e-12, -1.7584e-12],
#           [ 5.7485e-11, -5.5171e-11,  3.8820e-11,  1.3325e-10, -4.5872e-11],
#           [-3.7499e-11, -2.3732e-11,  1.5055e-11,  7.9304e-11, -3.0293e-12],
#           [-6.6752e-11, -2.7010e-11, -2.0018e-11,  6.4026e-11,  5.8703e-11]]]])
